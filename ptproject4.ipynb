# %% [markdown]
# # **(1)Import required libraries and read the dataset.**

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/data set/Apps_data+(1).csv')

# %% [markdown]
# # **(2.) Check the first few samples, shape, info of the data and try to familiarize yourself with different features.**

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.shape  #here 10841 rows and 13 columns are present
# Out:
# (10841, 13)

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df['Rating'].median()
# Out:
# 4.3

# %%
df['Rating'].fillna(4.3,inplace=True)

# %%
df['Type'].mode()
# Out:
# 0    Free
# Name: Type, dtype: object

# %%
df['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %%
df.loc[df['Type']=='0',['Type']]='Free' #here another type (0) present . we have to chenge it to mode value

# %%
df['Content Rating'].mode()
# Out:
# 0    Everyone
# Name: Content Rating, dtype: object

# %%
df['Content Rating'].fillna('Everyone',inplace=True)

# %%
df['Content Rating'].isnull().sum()
# Out:
# 0

# %%
df['Current Ver'].mode()
# Out:
# 0    Varies with device
# Name: Current Ver, dtype: object

# %%
df['Current Ver'].fillna('Varies with device',inplace=True)

# %%
df['Android Ver'].value_counts()
# Out:
# 4.1 and up            2451
# 4.0.3 and up          1501
# 4.0 and up            1375
# Varies with device    1362
# 4.4 and up             980
# 2.3 and up             652
# 5.0 and up             601
# 4.2 and up             394
# 2.3.3 and up           281
# 2.2 and up             244
# 4.3 and up             243
# 3.0 and up             241
# 2.1 and up             134
# 1.6 and up             116
# 6.0 and up              60
# 7.0 and up              42
# 3.2 and up              36
# 2.0 and up              32
# 5.1 and up              24
# 1.5 and up              20
# 4.4W and up             12
# 3.1 and up              10
# 2.0.1 and up             7
# 8.0 and up               6
# 7.1 and up               3
# 4.0.3 - 7.1.1            2
# 5.0 - 8.0                2
# 1.0 and up               2
# 7.0 - 7.1.1              1
# 4.1 - 7.1.1              1
# 5.0 - 6.0                1
# 2.2 - 7.1.1              1
# 5.0 - 7.1.1              1
# Name: Android Ver, dtype: int64

# %%
df['Android Ver'].fillna('4.1 and up',inplace=True)

# %% [markdown]
# # **(3.) Check summary statistics of the dataset. List out the columns that need to be worked upon for model**

# %%
df[df['Last Updated']=='1.0.19']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs  Type     Price Content Rating             Genres  \
# 10472  1,000+     Free  Free  Everyone       Everyone  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up  4.1 and up

# %%
df['Last Updated'].mode()
# Out:
# 0    August 3, 2018
# Name: Last Updated, dtype: object

# %%
df.loc[df['Last Updated']=='1.0.19',['Last Updated']]='August 3, 2018'

# %%
df['Genres'].mode()
# Out:
# 0    Tools
# Name: Genres, dtype: object

# %%
df.loc[df['Genres']=='February 11, 2018',['Genres']]='Tools'

# %%
df['Last Updated']=pd.to_datetime(df['Last Updated'],format='%B %d, %Y')

# %%
df['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10841, dtype: datetime64[ns]

# %%
df.describe(include=['object'])
# Out:
#            App Category Reviews                Size    Installs   Type  Price  \
# count    10841    10841   10841               10841       10841  10840  10841
# unique    9660       34    6002                 462          22      2     93
# top     ROBLOX   FAMILY       0  Varies with device  1,000,000+   Free      0
# freq         9     1972     596                1695        1579  10040  10040
#
#        Content Rating Genres         Current Ver Android Ver
# count           10841  10841               10841       10841
# unique              6    119                2832          33
# top          Everyone  Tools  Varies with device  4.1 and up
# freq             8715    843                1467        2454

# %% [markdown]
# # **4. Check if there are any duplicate records in the dataset? if any drop them**

# %%
df['App'].value_counts()  #there are many duplicate records
# Out:
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: App, Length: 9660, dtype: int64

# %%
df=df.drop_duplicates(subset=['App'])   #we drop the duplicate records

# %% [markdown]
# # **5. Check the unique categories of the column 'Category', Is there any invalid category? If yes, drop them**

# %%
df['Category'].value_counts()
# Out:
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# ART_AND_DESIGN           64
# EVENTS                   64
# PARENTING                60
# COMICS                   56
# BEAUTY                   53
# ...

# %%
df=df[~(df['Category']=='1.9')]

# %% [markdown]
# # **(6.) Check if there are missing values present in the column Rating, If any? drop them and and create a new**
# column as 'Rating_category' by converting ratings to high and low categories(>3.5 is high rest low)

# %%
#there are 1474 no of null values. i already done this in q2

# %%
df['Rating'].isnull().sum()
# Out:
# 0

# %%
df[df['Rating']>3.5]['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 4. , 4.8, 4.9, 3.6,
#        3.7, 5. ])

# %%
len(df[df['Rating']>3.5]['Rating'].unique())
# Out:
# 15

# %%
df[df['Rating']<3.6]['Rating'].unique()  #24 len
# Out:
# array([3.2, 3.3, 3.4, 3.5, 3.1, 2.6, 3. , 1.9, 2.5, 2.8, 2.7, 1. , 2.9,
#        2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
#high
hg=pd.DataFrame({'Rating':df[df['Rating']>3.5]['Rating'].unique(),'High':['high' for n in range(15)]})

# %%
#low
lw=pd.DataFrame({'Rating':df[df['Rating']<3.6]['Rating'].unique(),'Low':['low' for n in range(24)]})

# %%
gl=pd.concat([hg,lw],axis=0)

# %%
gl.drop('Low',axis=1,inplace=True)

# %%
gl.loc[gl['High'].isnull(),['High']]='low'

# %%
gl
# Out:
#     Rating  High
# 0      4.1  high
# 1      3.9  high
# 2      4.7  high
# 3      4.5  high
# 4      4.3  high
# 5      4.4  high
# 6      3.8  high
# 7      4.2  high
# 8      4.6  high
# 9      4.0  high
# 10     4.8  high
# 11     4.9  high
# 12     3.6  high
# 13     3.7  high
# 14     5.0  high
# 0      3.2   low
# 1      3.3   low
# 2      3.4   low
# 3      3.5   low
# 4      3.1   low
# 5      2.6   low
# 6      3.0   low
# 7      1.9   low
# 8      2.5   low
# 9      2.8   low
# 10     2.7   low
# 11     1.0   low
# 12     2.9   low
# 13     2.3   low
# 14     2.2   low
# 15     1.7   low
# 16     2.0   low
# 17     1.8   low
# 18     2.4   low
# 19     1.6   low
# 20     2.1   low
# 21     1.4   low
# 22     1.5   low
# 23     1.2   low

# %%
gl.rename(columns={'High':'Rating_category'},inplace=True)

# %%
df=pd.merge(df,gl,on='Rating',how='inner')

# %%
df
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                   Infinite Painter  ART_AND_DESIGN     4.1
# 2          Boys Photo Editor - Six Pack & Men's Suit  ART_AND_DESIGN     4.1
# 3                              Animated Photo Editor  ART_AND_DESIGN     4.1
# 4                    Easy Realistic Drawing Tutorial  ART_AND_DESIGN     4.1
# ...                                              ...             ...     ...
# 9654                                         Quiz DC            GAME     1.4
# 9655                                CB Mobile Access         FINANCE     1.5
# 9656                                        CF Climb       LIFESTYLE     1.5
# 9657                                     FK Atlantas          SPORTS     1.5
# 9658                                      EY TaxChat         FINANCE     1.2
#
# ...

# %% [markdown]
# # **(7.)Check the distribution of the newly created column 'Rating_category' and comment on the distribution**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=[4,4])
plt.hist(df['Rating_category'], color='purple')
plt.title('Distribution of Rating_category')
plt.xlabel('Values')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # **(8.) Convert the column "Reviews'' to numeric data type and check the presence of outliers in the column and**
# # handle the outliers using a transformation approach.**Hint**: Use log transformation

# %%
df['Reviews']=df['Reviews'].astype(int)

# %%
sns.boxenplot(df['Reviews'])
plt.show()

# %%
import numpy as np

# %%
np.log10(df['Reviews'])
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0       2.201397
# 1       4.566025
# 2       2.815578
# 3       2.307496
# 4       2.348305
#           ...
# 9654    1.518514
# 9655    1.755875
# 9656    0.301030
# 9657    0.301030
# 9658    1.643453
# Name: Reviews, Length: 9659, dtype: float64

# %% [markdown]
# # (9.) The column 'Size' contains alphanumeric values, treat the non numeric data and convert the column into
# **suitable data type. hint: Replace M with 1 million and K with 1 thousand, and drop the entries where**
# size='Varies with device'

# %%
def convert_size(value):
    if value == 'Varies with device':
        return None
    elif 'M' in value:
        return float(value.replace('M', '')) * 1e6
    elif 'k' in value:
        return float(value.replace('k', '')) * 1e3
    else:
        return float(value)

# %%
df['Size'].apply(convert_size)
# Out:
# 0       19000000.0
# 1       29000000.0
# 2       12000000.0
# 3        6100000.0
# 4        4200000.0
#            ...
# 9654     3100000.0
# 9655    25000000.0
# 9656     3000000.0
# 9657    26000000.0
# 9658    27000000.0
# Name: Size, Length: 9659, dtype: float64

# %%
df['Size']=df['Size'].apply(convert_size)

# %%
df=df[~(df['Size'].isnull())]

# %% [markdown]
# # **bold text**(10.) Check the column 'Installs', treat the unwanted characters and convert the column into a suitable data type.

# %%
df['Installs']
# Out:
# 0         10000
# 1       1000000
# 2        100000
# 3        100000
# 4        100000
#          ...
# 9654       1000
# 9655       1000
# 9656        100
# 9657          5
# 9658       1000
# Name: Installs, Length: 8432, dtype: object

# %%
df['Installs']=[n.replace(',','').replace('+','') for n in df['Installs']]
# Out:
# <ipython-input-577-65058ae9e14a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Installs']=[n.replace(',','').replace('+','') for n in df['Installs']]

# %%
df['Installs']=df['Installs'].astype(int)
# Out:
# <ipython-input-581-376db1f10a8a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Installs']=df['Installs'].astype(int)

# %% [markdown]
# # **11. Check the column 'Price' , remove the unwanted characters and convert the column into a suitable data type.**

# %%
df['Price'].value_counts()
# Out:
# 0          7747
# $0.99       142
# $2.99       110
# $1.99        66
# $4.99        63
#            ...
# $1.26         1
# $1.76         1
# $1.04         1
# $2.59         1
# $379.99       1
# Name: Price, Length: 87, dtype: int64

# %%
df['Price']=[n.replace('$','') for n in df['Price']]
# Out:
# <ipython-input-592-d05e6414fc92>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price']=[n.replace('$','') for n in df['Price']]

# %%
df['Price']=df['Price'].astype(float)
# Out:
# <ipython-input-598-9eb81e080c0a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price']=df['Price'].astype(float)

# %%
df['Price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# 12. Drop the columns which you think redundant for the analysis.(suggestion: drop column 'rating', since we
# created a new feature from it (i.e. rating_category) and the columns 'App', 'Rating' ,'Genres','Last Updated',
# 'Current Ver','Android Ver' columns since which are redundant for our analysis)
# # **bold text**

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Rating_category'],
#       dtype='object')

# %%
df.drop(columns=['Rating','App','Rating','Genres','Last Updated','Current Ver','Android Ver'],axis=0,inplace=True)
# Out:
# <ipython-input-607-ad29adbd49fe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Rating','App','Rating','Genres','Last Updated','Current Ver','Android Ver'],axis=0,inplace=True)

# %% [markdown]
# # **13. Encode the categorical columns**

# %%
df.columns
# Out:
# Index(['Category', 'Reviews', 'Size', 'Installs', 'Type', 'Price',
#        'Content Rating', 'Rating_category'],
#       dtype='object')

# %%
df
# Out:
#             Category  Reviews        Size  Installs  Type  Price  \
# 0     ART_AND_DESIGN      159  19000000.0     10000  Free    0.0
# 1     ART_AND_DESIGN    36815  29000000.0   1000000  Free    0.0
# 2     ART_AND_DESIGN      654  12000000.0    100000  Free    0.0
# 3     ART_AND_DESIGN      203   6100000.0    100000  Free    0.0
# 4     ART_AND_DESIGN      223   4200000.0    100000  Free    0.0
# ...              ...      ...         ...       ...   ...    ...
# 9654            GAME       33   3100000.0      1000  Free    0.0
# 9655         FINANCE       57  25000000.0      1000  Free    0.0
# 9656       LIFESTYLE        2   3000000.0       100  Free    0.0
# 9657          SPORTS        2  26000000.0         5  Free    0.0
# 9658         FINANCE       44  27000000.0      1000  Free    0.0
#
#      Content Rating Rating_category
# 0          Everyone            high
# 1          Everyone            high
# 2          Everyone            high
# 3          Everyone            high
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
#Category
df['Category']=lb.fit_transform(df['Category'])
# Out:
# <ipython-input-614-e56dce8fc17d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category']=lb.fit_transform(df['Category'])

# %%
#Type
df['Type']=lb.fit_transform(df['Type'])
# Out:
# <ipython-input-617-86ddc9f276d1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Type']=lb.fit_transform(df['Type'])

# %%
df['Type'].nunique()
# Out:
# 2

# %%
#Content Rating
df['Content Rating']=lb.fit_transform(df['Content Rating'])
# Out:
# <ipython-input-622-274de9840a22>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Content Rating']=lb.fit_transform(df['Content Rating'])

# %%
#Rating_category
df['Rating_category']=lb.fit_transform(df['Rating_category'])
# Out:
# <ipython-input-630-4460d1fefc8c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rating_category']=lb.fit_transform(df['Rating_category'])

# %% [markdown]
# # 14.Segregate the target and independent features (Hint: Use Rating_category as the target)

# %%
df.columns
# Out:
# Index(['Category', 'Reviews', 'Size', 'Installs', 'Type', 'Price',
#        'Content Rating', 'Rating_category'],
#       dtype='object')

# %%
x=df[['Category', 'Reviews', 'Size', 'Installs', 'Type', 'Price',
       'Content Rating']]

# %%
y=df[['Rating_category']]

# %% [markdown]
# # **15. Split the dataset into train and test.**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#       Category  Reviews        Size  Installs  Type  Price  Content Rating
# 4978        23    18918  12000000.0   5000000     0   0.00               1
# 9467        11       89  35000000.0     10000     0   0.00               1
# 7121        14       20  34000000.0       100     0   0.00               3
# 8674        24       41   7800000.0      5000     0   0.00               1
# 9589        11       54   4300000.0     10000     0   0.00               1
# ...        ...      ...         ...       ...   ...    ...             ...
# 412         20      698   2400000.0    100000     0   0.00               2
# 2370         7        0   4400000.0        10     0   0.00               3
# 1358        32    14051   8700000.0    100000     1   3.99               1
# 234         22       44   3600000.0     10000     0   0.00               1
# 4009        11     1922   4700000.0    500000     0   0.00               1
#
# [6745 rows x 7 columns]

# %% [markdown]
# # **(16)Standardize the data, so that the values are within a particular range**

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train_standardized = scaler.fit_transform(x_train)
x_test_standardized = scaler.transform(x_test)

# %% [markdown]
# # **PART 2**

# %% [markdown]
# # **1. Import required libraries and read the dataset.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dm=pd.read_csv('/content/drive/MyDrive/data set/honeyproduction.csv')

# %% [markdown]
# # **2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features**

# %%
dm.head(10)
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
# 5    FL  230000.0           98  22540000.0   4508000.0        0.64
# 6    GA   75000.0           56   4200000.0    307000.0        0.69
# 7    HI    8000.0          118    944000.0     66000.0        0.77
# 8    ID  120000.0           50   6000000.0   2220000.0        0.65
# 9    IL    9000.0           71    639000.0    204000.0        1.19
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998
# 5  14426000.0  1998
# 6   2898000.0  1998
# 7    727000.0  1998
# 8   3900000.0  1998
# ...

# %%
dm.shape
# Out:
# (626, 8)

# %%
dm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %% [markdown]
# # **3. Display the percentage distribution of the data in each year using the pie chart**

# %%
k=dm[['year','stocks']].groupby('year').count()

# %%
k.reset_index(inplace=True)

# %%
k
# Out:
#     year  stocks
# 0   1998      43
# 1   1999      43
# 2   2000      43
# 3   2001      44
# 4   2002      44
# 5   2003      44
# 6   2004      41
# 7   2005      41
# 8   2006      41
# 9   2007      41
# 10  2008      41
# 11  2009      40
# 12  2010      40
# 13  2011      40
# 14  2012      40

# %%
label=k['year'].unique()

# %%
value=k['stocks'].values

# %%
plt.pie(value,labels=label,autopct="%1.1f%%")
plt.show()

# %% [markdown]
# # **4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.**

# %%
dm['priceperlb']
# Out:
# 0      0.72
# 1      0.64
# 2      0.59
# 3      0.62
# 4      0.70
#        ...
# 621    3.77
# 622    2.38
# 623    2.91
# 624    2.05
# 625    1.87
# Name: priceperlb, Length: 626, dtype: float64

# %%
sns.distplot(dm['priceperlb'])
plt.show()
# Out:
# <ipython-input-13-e43a2fe8c3db>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dm['priceperlb'])

# %%
#it is right skewed distribution
#here mode>median>mean

# %% [markdown]
# #**5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.**

# %%
dm['numcol']
# Out:
# 0       16000.0
# 1       55000.0
# 2       53000.0
# 3      450000.0
# 4       27000.0
#          ...
# 621      4000.0
# 622     62000.0
# 623      6000.0
# 624     60000.0
# 625     50000.0
# Name: numcol, Length: 626, dtype: float64

# %%
dm['prodvalue']
# Out:
# 0        818000.0
# 1       2112000.0
# 2       2033000.0
# 3      23157000.0
# 4       1361000.0
#           ...
# 621      618000.0
# 622     6050000.0
# 623      838000.0
# 624     8487000.0
# 625     4769000.0
# Name: prodvalue, Length: 626, dtype: float64

# %%
sns.scatterplot(x=dm['numcol'],y=dm['prodvalue'])
plt.show()

# %% [markdown]
# # **6. Plot and understand the relationship between categorical variable 'year' and a numerical variable**
# 'prodvalue' through boxplot, and write your findings.

# %%
sns.boxplot(x=dm['year'],y=dm['prodvalue'])
# Out:
# <Axes: xlabel='year', ylabel='prodvalue'>

# %% [markdown]
# # **7. Visualize and understand the relationship between the multiple pairs of variables throughout different years**
# using pairplot and add your inferences. use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year'

# %%
sns.pairplot(dm[['numcol','yieldpercol','totalprod','prodvalue','year']])
plt.show()

# %% [markdown]
# # **8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol',**
# 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
dm.columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')

# %%
dm[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
       'prodvalue']].corr()
# Out:
#                numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue
# numcol       1.000000     0.243515   0.953594  0.825929   -0.232701   0.912796
# yieldpercol  0.243515     1.000000   0.396252  0.367812   -0.358646   0.278977
# totalprod    0.953594     0.396252   1.000000  0.878830   -0.264499   0.907236
# stocks       0.825929     0.367812   0.878830  1.000000   -0.305867   0.728560
# priceperlb  -0.232701    -0.358646  -0.264499 -0.305867    1.000000  -0.089567
# prodvalue    0.912796     0.278977   0.907236  0.728560   -0.089567   1.000000

# %%
sns.heatmap(dm[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
       'prodvalue']].corr())
# Out:
# <Axes: >
