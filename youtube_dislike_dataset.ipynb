# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/data set/youtube_dislike_dataset (1).csv')

# %%
#(Q1)Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve topImport required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top
#5 and bottom 5 records.

# %%
df.head()   #top 5 Rows
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# 2      925281   11212       401            831
# 3     2641597   39131       441           3745
# 4      715724   32887       367           1067
#
#                                                 tags  \
# 0  football soccer ftbol alemn Bundesliga season ...
# 1  Migos Avalanche Quality Control Music/Motown R...
# 2
# 3  PRODUCE101JAPAN              JO1   TheSTAR STA...
# 4  retaining wall New Jersey highway Direct Conne...
#
#                                          description  \
# 0  Enjoy the best skills and goals from Jadon San...
# 1  Watch the the official video for Migos - "Aval...
# 2  Hannah Waddingham wins the Emmy for Supporting...
# 3  JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO\n\n---...
# 4  One of the most important (and innocuous) part...
#
#                                             comments
# 0  Respect to Dortmund fans,must be sad losing hi...
# 1  Migos just makes me want to live my live to th...
# 2  Hannah's energy bursts through any screen. Wel...
# 3  youngVer><  REN is really PERFECT. It's not ju...
# 4   Keep up with all my projects here: https://pr...

# %%
df.tail()  #bottom 5 Rows
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# 37418     2841917    20759      1049           2624
# 37419    13346678   720854      4426          90616
# 37420      252057    19198      1234           1471
# 37421     2252090    34063       868           2004
#
#                                                     tags  \
# 37417  Lil Tjay Steady Calling My Phone Calling My Ph...
# 37418  NBA G League Basketball game-0022000187 Lakers...
# 37419  MAMAMOO  WAW  WAW MAMAMOO WAW Where Are We Now...
# 37420  master masterpodcast lord lord vinheteiro z z ...
# 37421  Spurs Tottenham Hotspur   Tottenham Leicester ...
#
#                                              description  \
# 37417  Official video for "Calling My Phone" by Lil T...
# 37418  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  [MV]  (MAMAMOO) - Where Are We Now\n\nInstagra...
# 37420  DOCTOR HAIR\nhttps://www.thedoctorhair.com/?fb...
# 37421  Two minute highlights from Tottenham Hotspur's...
#
#                                                 comments
# 37417  'DESTINED 2 WIN' OUT NOW !! https://liltjay.ln...
# 37418  Montrezl Harrell is going crazy with the rebou...
# 37419  I honestly do not know why this song hit so ha...
# 37420  Foi um prazer passar esta tarde com vocs debat...
# 37421  Thank you Kane for everything you have given t...

# %%
#(Q2)Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df.shape , #that means there are 37422 Columns and 12 Rows
# Out:
# ((37422, 12),)

# %%
df.info()   #most of the columns having intiser , object/string values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
#(Q3)Check for the Percentage of the missing values and drop or impute them

# %%
df.isnull().sum() #Here droping of the 'comments' column rather than fillinng is suitable for this data set
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
df['comments'].nunique()
# Out:
# 37264

# %%
df.drop(['comments'],axis=1,inplace=True)

# %%
#(Q4)Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 3.1+ MB

# %%
df[['view_count','likes','dislikes','comment_count']].describe()  #All 'numerical' Columns
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
df.describe(include='object') #all string/obj column
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#          tags description published_month
# count   37422       37422           37422
# unique  28799       35630              12
# top                               October
# freq     3817         589            4991

# %%
#(Q5)Convert datatype of column published_at from object to pandas datetime

# %%
df['published_at'].dtype  #here it is object type data type
# Out:
# dtype('O')

# %%
df['published_at']=pd.to_datetime(df['published_at'],utc=True)  #i convert this into datetime

# %%
#(Q6)Create a new column as 'published_month' using the column published_at (display the months only)

# %%
import datetime as dt

# %%
df['published_month']=df['published_at'].dt.month

# %%
#(Q7)Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'
#and so on.....

# %%
df['published_month']=df['published_at'].dt.month_name()

# %%
#(Q8)Find the number of videos published each month and arrange the months in a decreasing order based
#on the video count.

# %%
df.pivot_table(index=['published_month'],aggfunc='count',values=['video_id']).sort_values(by='video_id',ascending=False)
# Out:
#                  video_id
# published_month
# October              4991
# September            4880
# November             4851
# August               4262
# December             3072
# July                 2340
# June                 2316
# March                2258
# February             2137
# April                2126
# January              2108
# May                  2081

# %%
#(Q9)Find the count of unique video_id, channel_id and channel_title

# %%
df['video_id'].nunique()
# Out:
# 37422

# %%
df['channel_id'].nunique()
# Out:
# 10961

# %%
df['channel_title'].nunique()
# Out:
# 10883

# %%
#(Q10)Find the top10 channel names having the highest number of videos in the dataset and the bottom10
#having lowest number of videos.

# %%
dk=df.pivot_table(index='channel_title',aggfunc='count',values=['video_id']).sort_values(by='video_id',ascending=False)

# %%
dk.head(10)
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
dk.tail(10)
# Out:
#                 video_id
# channel_title
# Karchez                1
# Karate Combat          1
# Kaptain Kuba           1
# Kanye West             1
# Kannur kitchen         1
# Kannada Cinema         1
# KanalD                 1
# Kanak News             1
# Kamille Ramos          1
# zoom                   1

# %%
#(Q11)Find the title of the video which has the maximum number of likes and the title of the video having
#minimum likes and write your inferences.

# %%
like=df.pivot_table(index='title',aggfunc='max',values='likes').sort_values(by='likes',ascending=False)

# %%
like.head(1)
# Out:
#                                   likes
# title
# BTS () 'Dynamite' Official MV  31837675

# %%
like.tail(1)
# Out:
#                                                     likes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...      0

# %%
# (Q12)Find the title of the video which has the maximum number of dislikes and the title of the video having
#minimum dislikes and write your inferences.

# %%
dl=df.pivot_table(index='title',aggfunc='max',values='dislikes').sort_values(by='dislikes',ascending=False)

# %%
dl.head(1)   #top dislike video titel
# Out:
#                                      dislikes
# title
# Cuties | Official Trailer | Netflix   2397733

# %%
dl.tail(1)    #least sidlike video titel
# Out:
#                                                     dislikes
# title
# Kim Kardashian's Must-See Moments on "Saturday ...         0

# %%
# (Q13)Does the number of views have any effect on how many people disliked the video? Support your
#answer with a metric and a plot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lineplot(x=df['view_count'],y=df['dislikes'])
# Out:
# <Axes: xlabel='view_count', ylabel='dislikes'>

# %%
#as the view incease the dislike get more

# %%
# (Q14)Display all the information about the videos that were published in January, and mention the count of
#videos that were published in January.

# %%
jan=df[df['published_month']=='January']

# %%
jan.describe()
# Out:
#          view_count         likes       dislikes  comment_count
# count  2.108000e+03  2.108000e+03    2108.000000   2.108000e+03
# mean   4.976449e+06  1.315030e+05    3614.568311   8.923385e+03
# std    2.055331e+07  3.886887e+05   13946.711333   3.664662e+04
# min    2.845000e+04  2.800000e+01       3.000000   0.000000e+00
# 25%    4.322335e+05  1.032400e+04     249.000000   8.747500e+02
# 50%    1.147500e+06  3.173900e+04     729.000000   2.328500e+03
# 75%    3.227483e+06  1.076512e+05    2243.250000   6.302000e+03
# max    6.203274e+08  7.828036e+06  409144.000000   1.095119e+06

# %%
jk=df.pivot_table(index='published_month',aggfunc='count',values='video_id')

# %%
jk[jk.index=='January']
# Out:
#                  video_id
# published_month
# January              2108

# %% [markdown]
# # **END**
